# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def factorial_stirling(n):
    if n< 11:
        print("low factorial! may not be accurate")
    return ((2*(np.pi)*n)**0.5)*((n/np.e)**n)
def factorial(n, approx= False): 
    current = n 
    result = 1
    if approx and n >20:  
        return factorial_stirling(n)   
    else:
        while current >1:
            result *= current
            current = current -1
        return result
def factorial_stirling(n):
    if n< 11:
        print("low factorial! may not be accurate")
    return ((2*(np.pi)*n)**0.5)*((n/np.e)**n)

def brute_binomial(n,p, k ): #this is the binomial distribution, as computed without any modification
    return factorial(n)/(factorial(k)*factorial(n-k))*(p**k)*((1-p)**(n-k))
